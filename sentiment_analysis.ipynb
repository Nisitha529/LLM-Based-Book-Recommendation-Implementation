# %%
import pandas as pd
import numpy as np

from tqdm import tqdm

from transformers import pipeline

# %%
books      = pd.read_csv("books_with_categories.csv")
classifier = pipeline("text-classification", model = "j-hartmann/emotion-english-distilroberta-base", top_k = None)
# Out:
# Device set to use cpu

# %%
classifier("I love this!")
# Out:
# [[{'label': 'joy', 'score': 0.9771687984466553},
#   {'label': 'surprise', 'score': 0.008528684265911579},
#   {'label': 'neutral', 'score': 0.005764591973274946},
#   {'label': 'anger', 'score': 0.004419785924255848},
#   {'label': 'sadness', 'score': 0.002092393347993493},
#   {'label': 'disgust', 'score': 0.001611992483958602},
#   {'label': 'fear', 'score': 0.0004138524236623198}]]

# %%
emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surpirse", "neutral"]
isbn           = []
emotion_scores = {label : [] for label in emotion_labels}

def calculate_max_emotion_scores(predictions):
  per_emotion_scores = {label : [] for label in emotion_labels}
  for prediction in predictions:
    sorted_predictions = sorted(prediction, key = lambda x : x["label"])
    for index, label in enumerate(emotion_labels):
      per_emotion_scores[label].append(sorted_predictions[index]["score"])
  return {label: np.max(scores) for label, scores in per_emotion_scores.items()}

for i in range(10):
  isbn.append(books["isbn13"][i])
  sentences   = books["description"][i].split(".")
  predictions = classifier(sentences)
  max_scores  = calculate_max_emotion_scores(predictions)
  for label in emotion_labels:
    emotion_scores[label].append(max_scores[label])

print(emotion_scores)
# Out:
# {'anger': [np.float64(0.0641336739063263), np.float64(0.6126192212104797), np.float64(0.0641336739063263), np.float64(0.3514849543571472), np.float64(0.08141248673200607), np.float64(0.23222453892230988), np.float64(0.5381843447685242), np.float64(0.0641336739063263), np.float64(0.30066990852355957), np.float64(0.0641336739063263)], 'disgust': [np.float64(0.273592084646225), np.float64(0.348284512758255), np.float64(0.10400678217411041), np.float64(0.15072233974933624), np.float64(0.18449552357196808), np.float64(0.7271750569343567), np.float64(0.15585479140281677), np.float64(0.10400678217411041), np.float64(0.279481440782547), np.float64(0.17792588472366333)], 'fear': [np.float64(0.9281684160232544), np.float64(0.9425276517868042), np.float64(0.9723207950592041), np.float64(0.3607054650783539), np.float64(0.09504339098930359), np.float64(0.051362860947847366), np.float64(0.7474274039268494), np.float64(0.40449756383895874), np.float64(0.9155241250991821), np.float64(0.051362860947847366)], 'joy': [np.float64(0.9327981472015381), np.float64(0.7044220566749573), np.float64(0.7672385573387146), np.float64(0.25188079476356506), np.float64(0.04056445509195328), np.float64(0.043375857174396515), np.float64(0.8725658655166626), np.float64(0.04056445509195328), np.float64(0.04056445509195328), np.float64(0.04056445509195328)], 'sadness': [np.float64(0.6462154984474182), np.float64(0.8879395127296448), np.float64(0.5494765043258667), np.float64(0.7326849102973938), np.float64(0.8843895196914673), np.float64(0.6213917136192322), np.float64(0.7121937870979309), np.float64(0.5494765043258667), np.float64(0.8402889370918274), np.float64(0.8603722453117371)], 'surpirse': [np.float64(0.9671575427055359), np.float64(0.11169024556875229), np.float64(0.11169024556875229), np.float64(0.11169024556875229), np.float64(0.47588038444519043), np.float64(0.11169024556875229), np.float64(0.4080007076263428), np.float64(0.8202823996543884), np.float64(0.35446107387542725), np.float64(0.11169024556875229)], 'neutral': [np.float64(0.7296022176742554), np.float64(0.2525462210178375), np.float64(0.07876549661159515), np.float64(0.07876549661159515), np.float64(0.07876549661159515), np.float64(0.2719036638736725), np.float64(0.07876549661159515), np.float64(0.234486922621727), np.float64(0.13561400771141052), np.float64(0.07876549661159515)]}

# %%
emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn           = []
emotion_scores = {label : [] for label in emotion_labels}

for i in tqdm (range(len(books))):
  isbn.append(books["isbn13"][i])
  sentences   = books["description"][i].split(".")
  predictions = classifier(sentences)
  max_scores  = calculate_max_emotion_scores(predictions)
  for label in emotion_labels:
    emotion_scores[label].append(max_scores[label])

emotions_df = pd.DataFrame(emotion_scores)
emotions_df["isbn13"] = isbn
print(emotions_df.head())
# Out:
# 100%|██████████| 5197/5197 [1:02:08<00:00,  1.39it/s]
#       anger   disgust      fear       joy   sadness  surprise   neutral  \
# 0  0.064134  0.273592  0.928168  0.932798  0.646215  0.967158  0.729602
# 1  0.612619  0.348285  0.942528  0.704422  0.887940  0.111690  0.252546
# 2  0.064134  0.104007  0.972321  0.767239  0.549477  0.111690  0.078765
# 3  0.351485  0.150722  0.360705  0.251881  0.732685  0.111690  0.078765
# 4  0.081412  0.184496  0.095043  0.040564  0.884390  0.475880  0.078765
#
#           isbn13
# 0  9780002005883
# 1  9780002261982
# 2  9780006178736
# 3  9780006280897
# 4  9780006280934

# %%
books = pd.merge(books, emotions_df, on = "isbn13")
print(books)
books.to_csv("books_with_emotions.csv", index = False)
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ...  \
# 0               3.85      247.0  ...
# 1               3.83      241.0  ...
# 2               3.93      512.0  ...
# 3               4.15      170.0  ...
# 4               4.09      176.0  ...
# ...              ...        ...  ...
# 5192            2.93      324.0  ...
# 5193            3.70      175.0  ...
# 5194            3.82      198.0  ...
# 5195            4.51      531.0  ...
# 5196            0.00      210.0  ...
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195     I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories  \
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...        Nonfiction
# 4     9780006280934 "In The Problem of Pain, C.S. Le...        Nonfiction
# ...                                                 ...               ...
# 5192  9788172235222 On A Train Journey Home To North...           Fiction
# 5193  9788173031014 This book tells the tale of a ma...        Nonfiction
# 5194  9788179921623 Wisdom to Create a Life of Passi...           Fiction
# 5195  9788185300535 This collection of the timeless ...        Nonfiction
# 5196  9789027712059 Since the three volume edition o...        Nonfiction
#
#          anger   disgust      fear       joy   sadness  surprise   neutral
# 0     0.064134  0.273592  0.928168  0.932798  0.646215  0.967158  0.729602
# 1     0.612619  0.348285  0.942528  0.704422  0.887940  0.111690  0.252546
# 2     0.064134  0.104007  0.972321  0.767239  0.549477  0.111690  0.078765
# 3     0.351485  0.150722  0.360705  0.251881  0.732685  0.111690  0.078765
# 4     0.081412  0.184496  0.095043  0.040564  0.884390  0.475880  0.078765
# ...        ...       ...       ...       ...       ...       ...       ...
# 5192  0.148209  0.030643  0.919165  0.255172  0.853721  0.980877  0.030656
# 5193  0.064134  0.114383  0.051363  0.400263  0.883198  0.111690  0.227765
# 5194  0.009997  0.009929  0.339217  0.947779  0.375755  0.066685  0.057625
# 5195  0.064134  0.104007  0.459269  0.759457  0.951104  0.368111  0.078765
# 5196  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078765
#
# [5197 rows x 21 columns]
